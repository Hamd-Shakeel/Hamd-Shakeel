# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamd-Shakeel/Hamd-Shakeel/blob/main/Coursera_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
requests.get('https://www.coursera.org/certificates/computer-science-it',headers=headers).text
# Out:
# '<!DOCTYPE html><html xmlns:fb="http://ogp.me/ns/fb#" itemtype="http://schema.org" lang="en" dir="ltr"><head><link rel="preconnect" href="https://d3njjcbhbojbot.cloudfront.net" crossorigin><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7"><meta charset="utf-8"><meta property="og:site_name" content="Coursera"><meta property="fb:admins" content="727836538,4807654"><meta property="fb:app_id" content="823425307723964"><meta name="twitter:site" content="Coursera"><meta name="twitter:app:name:iphone" content="Coursera"><meta name="twitter:app:name:ipad" content="Coursera"><meta name="twitter:app:name:googleplay" content="Coursera"><meta name="twitter:app:id:iphone" content="id736535961"><meta name="twitter:app:id:ipad" content="id736535961"><meta name="twitter:app:id:googleplay" content="org.coursera.android"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="apple-touch-icon" sizes="57x57" href="https://d3njjcbhbojbot.cloudfront.net/web/images/fav
# ...

# %%
webpage=requests.get('https://www.coursera.org/certificates/computer-science-it',headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())

# %%
soup.find_all('p')[0].text.strip()

# %%
for i in soup.find_all('p'):
  print(i.text.strip())

# %%
company=soup.find_all('p',class_="cds-119 cds-Typography-base css-j2b34a cds-121")

# %%
company
# Out:
# [<p class="cds-119 cds-Typography-base css-j2b34a cds-121">Microsoft Cybersecurity Analyst Professional Certificate</p>,
#  <p class="cds-119 cds-Typography-base css-j2b34a cds-121">AWS Cloud Technology Consultant Professional Certificate</p>,
#  <p class="cds-119 cds-Typography-base css-j2b34a cds-121">IBM IT Project Manager Professional Certificate</p>,
#  <p class="cds-119 cds-Typography-base css-j2b34a cds-121"> IBM and ISC2 Cybersecurity Specialist Professional Certificate</p>,
#  <p class="cds-119 cds-Typography-base css-j2b34a cds-121">Google Cybersecurity Professional Certificate</p>,
#  <p class="cds-119 cds-Typography-base css-j2b34a cds-121">Meta iOS Developer Professional Certificate</p>,
#  <p class="cds-119 cds-Typography-base css-j2b34a cds-121">Meta Back-End Developer Professional Certificate</p>,
#  <p class="cds-119 cds-Typography-base css-j2b34a cds-121">Meta Database Engineer Professional Certificate</p>,
# ...

# %%
name = [i.text for i in company]

# %%
name
# Out:
# ['Microsoft Cybersecurity Analyst Professional Certificate',
#  'AWS Cloud Technology Consultant Professional Certificate',
#  'IBM IT Project Manager Professional Certificate',
#  ' IBM and ISC2 Cybersecurity Specialist Professional Certificate',
#  'Google Cybersecurity Professional Certificate',
#  'Meta iOS Developer Professional Certificate',
#  'Meta Back-End Developer Professional Certificate',
#  'Meta Database Engineer Professional Certificate',
#  'IBM Cybersecurity Analyst Professional Certificate',
#  'SAP Technology Consultant  Professional Certificate',
#  'IBM Front-End Developer Professional Certificate',
#  'Meta Front-End Developer Professional Certificate',
#  'IBM Full-Stack JavaScript Developer Professional Certificate',
#  'IBM Back-end JavaScript Developer Professional Certificate',
#  'Meta Android Developer Professional Certificate',
#  'IBM DevOps and Software Engineering Professional Certificate',
# ...

# %%
company=soup.find_all('p',class_="cds-119 css-1ncjvum cds-121")
company
# Out:
# [<p class="cds-119 css-1ncjvum cds-121">Offered by Microsoft</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by Amazon Web Services</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by SkillUp EdTech</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by IBM</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by Google</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by Meta</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by Meta</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by Meta</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by IBM</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by SAP</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by IBM</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by Meta</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by IBM</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by IBM</p>,
#  <p class="cds-119 css-1ncjvum cds-121">Offered by Meta</p>,
# ...

# %%
offered_by = [i.text for i in company]
offered_by
# Out:
# ['Offered by Microsoft',
#  'Offered by Amazon Web Services',
#  'Offered by SkillUp EdTech',
#  'Offered by IBM',
#  'Offered by Google',
#  'Offered by Meta',
#  'Offered by Meta',
#  'Offered by Meta',
#  'Offered by IBM',
#  'Offered by SAP',
#  'Offered by IBM',
#  'Offered by Meta',
#  'Offered by IBM',
#  'Offered by IBM',
#  'Offered by Meta',
#  'Offered by IBM',
#  'Offered by IBM',
#  'Offered by IBM',
#  'Offered by IBM',
#  'Offered by Google',
#  'Offered by Google',
#  'Offered by Akamai Technologies, Inc.',
#  'Offered by Akamai Technologies, Inc.',
#  'Offered by LearnQuest',
#  'Offered by Meta',
#  'Offered by Amazon Web Services',
#  'Offered by Google Cloud',
#  'Offered by Google',
#  'Offered by IBM',
#  'Offered by Microsoft',
#  'Offered by Microsoft',
#  'Offered by Google Cloud',
#  'Offered by Palo Alto Networks',
#  'Offered by Google Cloud',
#  'Offered by Google Cloud',
#  'Offered by Google Cloud',
#  'Offered by Google Cloud',
# ...

# %%
company=soup.find_all('p',class_="cds-119 css-rwrfuo cds-121")
company
# Out:
# [<p class="cds-119 css-rwrfuo cds-121">6 months at 10 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">6 months at 4 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">3 months at 10 hours a week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">3 months at 10 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">6 months at 7 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">8 months at 7 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">8 months at 6 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">6 months at 6 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">8 months at 4 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">7 months at 3 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">9 months at 3 hours a week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">7 months at 6 hours per week</p>,
#  <p class="cds-119 css-rwrfuo cds-121">5 months at 10 hours a week</p>,
# ...

# %%
duration=[i.text for i in company]
duration
# Out:
# ['6 months at 10 hours per week',
#  '6 months at 4 hours per week',
#  '3 months at 10 hours a week',
#  '3 months at 10 hours per week',
#  '6 months at 7 hours per week',
#  '8 months at 7 hours per week',
#  '8 months at 6 hours per week',
#  '6 months at 6 hours per week',
#  '8 months at 4 hours per week',
#  '7 months at 3 hours per week',
#  '9 months at 3 hours a week',
#  '7 months at 6 hours per week',
#  '5 months at 10 hours a week',
#  '5 months at 10 hours a week',
#  '8 months at 7 hours per week',
#  '9 months at 3 hours per week',
#  '9 months at 3 hours per week',
#  '12 months at 10 hours per week',
#  '7 months at 2 hours per week',
#  '6 months at 10 hours per week',
#  '6 months at 10 hours per week',
#  '6 months at 8 hours a week',
#  '5 months at 8 hours a week',
#  '6 months at 4 hours per week',
#  '3 months at 10 hours per week',
#  '4 months at 4 hours per week',
#  '2 months at 5 hours per week',
#  '6 months at 5 hours per week',
#  '',
# ...

# %%
company=soup.find_all('h3',class_="css-6fa31k")
company
# Out:
# [<h3 class="css-6fa31k">Professional Certificates</h3>,
#  <h3 class="css-6fa31k">MasterTrack Certificates</h3>,
#  <h3 class="css-6fa31k">University Certificates</h3>,
#  <h3 class="css-6fa31k">Graduate Certificates</h3>]

# %%
df=pd.DataFrame({'name':name,'offered_by':offered_by,'duration':duration})

# %%
df
# Out:
#                                                  name  \
# 0   Microsoft Cybersecurity Analyst Professional C...
# 1   AWS Cloud Technology Consultant Professional C...
# 2     IBM IT Project Manager Professional Certificate
# 3    IBM and ISC2 Cybersecurity Specialist Profess...
# 4       Google Cybersecurity Professional Certificate
# 5         Meta iOS Developer Professional Certificate
# 6    Meta Back-End Developer Professional Certificate
# 7     Meta Database Engineer Professional Certificate
# 8   IBM Cybersecurity Analyst Professional Certifi...
# 9   SAP Technology Consultant  Professional Certif...
# 10   IBM Front-End Developer Professional Certificate
# 11  Meta Front-End Developer Professional Certificate
# 12  IBM Full-Stack JavaScript Developer Profession...
# 13  IBM Back-end JavaScript Developer Professional...
# 14    Meta Android Developer Professional Certificate
# 15  IBM DevOps and Software Engineering Profession...
# ...

# %%
df.to_csv('coursera.csv')
